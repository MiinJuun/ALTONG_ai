# %% [markdown]
# # ALTONG briefing QLoRA training
# Run this notebook with a GPU runtime. It trains only on synthetic notifications and saves the adapter to Google Drive.

# %%
# !nvidia-smi

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone --branch feature/briefing-qwen-lora --single-branch https://github.com/AIoish/ALTONG_ai.git /content/ALTONG_ai
# %cd /content/ALTONG_ai

# %%
# !python -m pip install -q -r briefing_training/requirements-lora.txt

# %%
# !python -m briefing_training.prepare_dataset
# !python -m briefing_training.train_lora --validate-only

# %%
# !python -m briefing_training.train_lora --output-dir /content/drive/MyDrive/ALTONG_models/briefing-qwen-lora

# %% [markdown]
# ## Compare the base model and trained adapter
# Run both evaluations on the fixed eight-case set. The reports are saved next to the adapter in Google Drive.

# %%
# !python -m briefing_training.evaluate --output /content/drive/MyDrive/ALTONG_models/briefing-qwen-lora/base_evaluation.json

# %%
# !python -m briefing_training.evaluate --adapter-path /content/drive/MyDrive/ALTONG_models/briefing-qwen-lora --output /content/drive/MyDrive/ALTONG_models/briefing-qwen-lora/lora_evaluation.json
